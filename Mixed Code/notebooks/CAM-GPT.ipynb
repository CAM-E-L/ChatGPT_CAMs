# %%
cd ../
# Out:
# /Users/dara/Documents/ChatGPT_CAMs

# %% [markdown]
# Necessary Imports

# %%
import base64
import requests
import os
from src.encode_image import encode_image
from src.headers import headers
from src.api_key import api_key
from src.directory_path import directory_path
from src.iterate_files import iterate_files

# %% [markdown]
# We will iterate through all files in the specified directory which have '.jpg', '.jpeg' or '.png' formats. Feed them to the LLM through the API and get descriptions for each one.

# %%
iterate_files(directory_path)
# Out:
# Response for 69f05358-5076-4fd5-816d-34628af4f8ec.png:
# In the provided image, a conceptual map revolves around the central concept of "Covid-19," highlighted in yellow. From this central concept, two primary branches extend: one for positive aspects (green) and another for negative aspects (red).
#
# ### Positive Aspects:
# - **Awareness**: The concept is connected via "hospital."
# - **Hospital**: Intermediate node connecting awareness to positive aspects.
# - **Solidarity**: Directly associated with aid.
# - **Aid**: Connected through the term "solidarity."
#
# ### Negative Aspects:
# - **Unemployment**: Direct consequence of the negative aspects of Covid-19.
# - **Despair**: Results from unemployment.
# - **Fear**: Arises from negative aspects of Covid-19 and leads to:
#   - **Death**: One of the extreme consequences driven by fear.
#   - **Bad decisions**: Another outcome of fear.
# - **Bad Decisions**: Lead to further consequences.
# - **Consequences**: These stem from bad decisions influenced by fear.
#
# ### Summary:
# The image is a conceptual map illustrating the effects of Covid-19. The central concept of Covid-19 is shown to have both positive and negative aspects. Positive aspects include themes of awareness, hospital, solidarity, and aid, visualized in green. Negative aspects include themes of unemployment, despair, fear, death, bad decisions, and consequences, visualized in red. This map provides a clear depiction of the multifaceted impacts of the Covid-
#
# ==================================================
#
# Response for e7448017-7b06-4dc1-a36c-b40ff761e66a.png:
# The image is a concept map illustrating various associations with Covid-19. Different concepts are color-coded and connected through directional arrows, indicating the relationships between them.
#
# Here are the key concepts and their relationships:
#
# 1. **Covid-19 (Centered in Yellow)**
#     - **Positive Aspects**
#     - **Negative Aspects**
#     - **Death (Red)**
#         - Connected with an outward arrow indicating that Covid-19 leads to Death.
#
# 2. **Illness (Red)**
#     - Connected to Death with an arrow.
#     - Connected to the help of strangers (Purple).
#
# 3. **Availability of Medicine (Red)**
#     - Linked to Illness suggesting that the availability of medicine relates to handling illness.
#
# 4. **Trusted Information (Red)**
#     - Connected with an arrow from Availability of Medicine indicating that trusted information is essential.
#
# 5. **Attention to Self/Others (Green)**
#     - Connected to Family Unit, Change to Priorities, and Doctors/Nurses (small green nodes) implying that a greater emphasis on individuals from Covid-19 impacts these areas.
#
# 6. **Overall Health Awareness (Green)**
#     - Linked to Available Vaccines with an arrow indicating better health awareness leads to the use of vaccines.
#
# Overall, the concept map demonstrates how the Covid-19 pandemic is interrelated to various facets such as health awareness, medical availability, and societal behaviors, noting both positive and negative aspects.
#
# ### Summary:
# The image is a concept map centered
#
# ==================================================
#
# Response for e6021957-6e34-40af-ba65-d9742c984f6c.png:
# The image is a concept map centered on COVID-19, depicted by a yellow box. The map explores both positive and negative aspects related to the pandemic, which are presented in green and red boxes respectively.
#
# **Positive Aspects**:
# - **Social Distancing**: Linked to the central concept, COVID-19.
# - **Masks**: Connected as a positive aspect of dealing with the virus.
# - **Self Worth**: Included as a positive aspect.
# - **Understanding of Vaccination**: Highlighted as another benefit.
# - **Remote Jobs**: Seen as a positive outcome.
# - **Washing of Hands**: Also included in the positive aspects.
#
# **Negative Aspects**:
# - **Deaths**: A major negative impact.
# - **Country Divided**: Another negative outcome.
# - **It Became Political**: An aspect linked to division within the country.
# - **Racial Divide**: Also connected to the negative aspects.
#
# The visual relationships show that COVID-19 has both positive and negative consequences, with negative aspects further branching out into issues like deaths, politicization, and racial divides. Positive responses focus more on health measures, personal growth, and remote working opportunities.
#
# **Summary**:
# The concept map delineates the multifaceted impact of COVID-19. The pandemic has led to various positive outcomes, such as improved hygiene practices, social distancing, mask usage, an understanding of vaccinations, self-worth, and remote job opportunities. Conversely, it has also brought about significant
#
# ==================================================
#
# Response for 85fee014-08b7-4ea3-9453-0fe4a05658c4.png:
# This image is a network diagram showing various concepts associated with COVID-19 and visualizing the relationships between them. The concepts are represented as nodes in different colors, and the relationships between them are shown as directed arrows. Here’s a detailed breakdown of the elements:
#
# ### Nodes:
# - **Red Nodes:** Represent negative aspects or outcomes, such as:
#   - "Actually having covid"
#   - "Long covid"
#   - "Negative aspects"
#   - "Things being closed"
#   - "Side effects"
#   - "Exhausting political discourse"
#   - "Origin in Wuhan"
#   - "Immigration still restricted"
#   - "Xenophobia"
#   - "Lost income"
#   - "Taking away RW"
# - **Green Nodes:** Represent positive aspects or beneficial outcomes, such as:
#   - "Exercising outside more"
#   - "My gym"
#   - "Places reopening"
#   - "Saving lives"
#   - "Remote work"
#   - "Stimulus payments"
#   - "UBI maybe someday"
# - **Yellow Nodes:** Represent neutral or mixed-impact concepts, such as:
#   - "Masks"
#   - Positive aspects
# - **Purple Nodes:** Represent concepts related to human reactions and socio-political dimensions, such as:
#   - "Vaccines"
#   - "Schadenfreude"
#   - "Racism and xenophobia"
#   - "Shock doctrine"
#
# ### Key Relationships:
# - **COVID-19:** Central to many other concepts, showing
#
# ==================================================
#
# Response for 3cc77daa-903d-4fe8-830d-c134b3271a72.png:
# This image is a concept map depicting various aspects (both positive and negative) related to COVID-19 and their interrelationships.
#
# Key concepts within the image:
# 1. **Covid-19**: This is the central concept.
# 2. **Negative aspects**: Connected to Covid-19.
# 3. **Positive aspects**: Connected to Covid-19.
#
# ### Negative Aspects:
# - **Death**: Connected to negative aspects.
# - **Suspension of Travel**: Linked from negative aspects and connected to family connection.
# - **Family connection**: Connected from the suspension of travel.
# - **Online**: Linked from negative aspects.
#   - **Mental Health**: Connected from online.
#   - **Restaurants/Tourism**: Connected to online.
#   - **School**: Also connected to online.
#
# ### Positive Aspects:
# - **Unity**: Linked from positive aspects.
#   - **Wearing masks**: Connected to unity.
#   - **Supporting local businesses**: Connected to unity.
#   - **Getting vaccinated**: Connected to unity.
#
# ### Summary:
# The image maps out the various impacts of Covid-19 into two main categories: negative and positive aspects. On the negative side, it highlights issues such as death, the suspension of travel (affecting family connection), and the shift to online platforms affecting mental health, restaurants/tourism, and school. On the positive side, it emphasizes aspects such as unity through actions like wearing masks, supporting local businesses, and getting
#
# ==================================================
#
# Response for 16467e38-f3e3-4ccd-8cd4-803204b7ca5a.png:
# ### Description of Concepts and Relationships:
#
# 1. **Covid-19**:
#    - Central node with arrows pointing to two other nodes:
#      - **Negative aspects**: Indicating the negative effects of Covid-19.
#      - **Positive aspects**: Indicating the positive effects of Covid-19.
#
# 2. **Negative aspects**:
#    - This node is connected to several sub-nodes illustrating the negative outcomes related to Covid-19:
#      - **Large layoffs**: Substantial job losses.
#      - **depressing**
#      - **boring**
#      - **Isolating**
#      - **Bad response**
#
# 3. **Positive aspects**:
#    - This node is connected to several sub-nodes illustrating the positive outcomes related to Covid-19:
#      - **Family**
#      - **Free time**
#      - **Removed Trump**: Led to the removal of Trump.
#      - **Installed Biden**: Results from the removal of Trump.
#      - **Reduced fossil fuels**: This has further effects leading to:
#        - **Lower fuel prices**
#        - **Lower corporate pollution**: Following the reduction in fossil fuels.
#        - **Environment Benefits**: Resulting from lower corporate pollution.
#
# ### Summary:
# The image presents a concept map that delineates the various effects of Covid-19 divided into negative and positive aspects. The negative aspects include large layoffs, feelings of depression, boredom, isolation, and a bad response to the pandemic. On the positive side
#
# ==================================================
#
# Response for 766c179b-b06e-40b2-a784-379a1a543042.png:
# This image appears to be a concept map illustrating the relationships between different themes and concepts, likely related to the impacts of a global event such as COVID-19. Here are the key points and their relationships:
#
# 1. **Anxiety (Red)**:
#    - Connected to **Problem-solving (Green)**.
#    - Connected to **Stress (Red)**.
#    - Connected to **Mental health (Purple)**.
#    - Connected to **Negative aspects (Yellow)**.
#
# 2. **Stress (Red)**:
#    - Connected to **Negative aspects (Yellow)**.
#    - Connected to **Mental health (Purple)**.
#
# 3. **Mental health (Purple)**:
#    - Connected to **WFH (Working from Home) (Purple)**.
#
# 4. **WFH (Purple)**:
#    - Connected to **Negative aspects (Yellow)**.
#    - Connected to **Economic shock (Red)**.
#
# 5. **Negative aspects (Yellow)**:
#    - Connected to **Positive aspects (Yellow)**.
#    - Connected to **COVID-19 (Red)**.
#    - Connected to **WFH (Purple)**.
#    - Connected to **Economic shock (Red)**.
#
# 6. **Positive aspects (Yellow)**:
#    - Connected to **Community solidarity (Green)**.
#    - Connected to **Independence (Green)**.
#
# 7. **Independence (Green)**:
#    - Connected to **Self-assurance (Green)**.
#    - Connected to **Problem-solving (Green)**
#
# ==================================================
#
# Response for 4641b66c-4b02-4a71-9ff3-aa0f5b100ab8.png:
# This image appears to be a conceptual map or network diagram that demonstrates relationships between different concepts related to Covid-19.
#
# Key concepts and their relationships:
# 1. **Covid-19** (Yellow square in the center):
#    - Central node.
#    - Has outgoing connections to several other nodes.
#
# 2. **Negative Aspects** (Yellow square):
#    - Connected to and likely influenced by Covid-19.
#    - Influences:
#      - **Joblessness** (Red square)
#      - **Death** (Red square)
#      - **Worsened economic inequality** (Red square)
#      - **Hunger** (Red square)
#      - **Disrupted education** (Red square)
#
# 3. **Lockdown** (Green circle):
#    - Directly connected to Covid-19.
#    - Leads to **Positive Aspects** (Yellow square), which subsequently leads to **Connection** (Green circle).
#
# 4. **Positive Aspects** (Yellow square):
#    - Connected to the **Lockdown**.
#    - Leads to **Connection** (Green circle).
#
# 5. **Other Nodes** (in red):
#    - **Joblessness**: Directly connected to Covid-19.
#    - **Death**: Directly connected to Covid-19.
#    - **Worsened economic inequality**: Directly connected to Covid-19.
#    - **Hunger**: Directly connected to Covid-19.
#    - **Disrupted education**: Directly connected
#
# ==================================================
#
# Response for ea21c7e2-13e9-47e6-81b5-3d5dbea565e5.png:
# The image is a concept map related to Covid-19 highlighting its various impacts, divided into positive and negative aspects. The map uses different colors and shapes to distinguish concepts and their relationships. Here is the description:
#
# - **Central Concept**: "Covid-19" represented in a yellow square.
#     - From "Covid-19", there are two main branches, one leading to "negative aspects" and the other to "positive aspects."
#
# ### Negative Aspects (Yellow Square):
# - Branches from "negative aspects":
#     - Leads to "Fear" (red square):
#         - "Fear" has connections to:
#             - "shortages" (red square)
#             - "Mental health" (red square)
#                 - "Mental health" branches to:
#                     - "rampant polarity" (red square)
#                     - "Endless news cycle high stress situation" (red square)
#                         - "Endless news cycle high stress situation" branches to:
#                             - "lack of entertainment" (red square)
#
# ### Positive Aspects (Green Circle):
# - Branches from "positive aspects":
#     - Leads to:
#         - "Introspection" (green circle)
#         - "Vaccine technology advancement" (green circle)
#         - "Adjustment of Priorities" (green circle)
#
# ### Summary:
# Overall, the concept map shows the complex impacts of Covid-19. On the negative side, it highlights the rise in fear, shortages, and mental health issues, exacerbated by factors
#
# ==================================================
#
# Response for 36f50160-5b14-49c9-a455-1296a7b13fc7.png:
# The image appears to be a concept map relating to "Covid-19," illustrating various effects and related concepts.
#
# - The central node is labeled "Covid-19" in red.
#
# Directly linked to "Covid-19":
# - Negative aspects (yellow) including:
#   - "death" (red) connected to "suffering" (red)
#   - "isolation" (red)
#   - "unemployment" (red) further linked to "shortages" (red) and "inflation" (red)
#   - "shortages" (red) connected to "unemployment" (red)
#   - "mask-wearing" (red)
# - Positive aspects (green) including:
#   - "vaccines" (green)
#   - "technology use" (green)
#   - "remote work" (green)
#   - "positive aspects" (green)
# - Additionally, there is a direct connection to "negative aspects" (yellow)
#
# Summary:
# The concept map illustrates the complex impacts of Covid-19. It connects Covid-19 directly to various outcomes such as death, isolation, unemployment, shortages, inflation, and mask-wearing—all shown in red to indicate negative connotations. On the positive side, it links Covid-19 to vaccines, use of technology, remote work, and general positive aspects—all shown in green. The map highlights both the detrimental and beneficial effects of the pandemic.
#
# ==================================================
